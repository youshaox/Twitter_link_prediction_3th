# %% [markdown]
# # Load the data

# %%
import pandas as pd
import pickle
import math
import numpy as np
# import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

# %%
data_dir = "../../data/"
def save_obj(obj, name ):
    with open( name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name):
    with open(data_dir + name + '.pkl', 'rb') as f:
        return pickle.load(f)
# load data

training_data_v1 = load_obj("un_normalised_final_training_data_df_rf")
BasicFeatures = load_obj("pre_features-v2")
pre_features = BasicFeatures

# %% [markdown]
# # Explantory

# %%
import pandas as pd
# in-degree statistics
df = pd.DataFrame(BasicFeatures)
df =  df.T
df.rename(columns={0: 'num_of_neighbours',
                   1: 'log_num_of_neighbours',
                  2: 'list_of_neighbours',
                  3: 'list_of_in_neighbours',
                  4: 'num_of_in_neighbours',
                  5: 'list_of_out_neighbours',
                  6: 'num_of_out_neighbours'}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-74c88ab1ad3a> in <module>()
#       1 import pandas as pd
#       2 # in-degree statistics
# ----> 3 df = pd.DataFrame(BasicFeatures)
#       4 df =  df.T
#       5 df.rename(columns={0: 'num_of_neighbours',
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# ...

# %%
training_data_v1 = load_obj("un_normalised_final_training_data_df_rf")

# %%
df

# %%
# df.sort_values('num_of_neighbours',ascending=False)
# df_statistics = df[num_of_neighbours]
df_statistics = df[['num_of_neighbours', 'num_of_in_neighbours', 'num_of_out_neighbours']].copy()
df_statistics = df_statistics.astype(int)
df_statistics[['num_of_neighbours', 'num_of_in_neighbours', 'num_of_out_neighbours']]

# df_statistics.sort_values('num_of_neighbours',ascending=False)
print(df_statistics.describe())
# conclusion: num_of_out_neighbours is 3 times as largee as the num_of_in_neighbours for small num of data
# Out:
#        num_of_neighbours  num_of_in_neighbours  num_of_out_neighbours
# count       50000.000000           50000.00000           50000.000000
# mean           37.864600              10.16080              27.703800
# std          3498.361192              38.68534            3474.688858
# min             1.000000               1.00000               0.000000
# 25%             1.000000               1.00000               0.000000
# 50%             2.000000               2.00000               0.000000
# 75%             6.000000               6.00000               0.000000
# max        766634.000000            4841.00000          761793.000000

# %%
df_statistics.astype(int).hist(density=1)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fcae63f7048>,
# ...
#       dtype=object)

# %%
# df_statistics['log_num_of_neighbours'] = df_statistics['num_of_neighbours'].apply(lambda x: math.log(x))
# df_statistics['log_num_of_in_neighbours'] = df_statistics['num_of_in_neighbours'].apply(lambda x: math.log(x))
# df_statistics['log_num_of_out_neighbours'] = df_statistics['num_of_out_neighbours'].apply(lambda x: math.log(x))
for num in df_statistics['num_of_out_neighbours']:
    if num<0:
        print(num)

# %%
# num_of_neighbours
# 设置图形的显示风格
plt.style.use('ggplot')
# 绘图：乘客年龄的频数直方图
arr = plt.hist(df_statistics.num_of_neighbours, # 绘图数据
        bins = 15, # 指定直方图的条形数为20个
        color = 'steelblue', # 指定填充色
        edgecolor = 'k', # 指定直方图的边界色
        label = 'num_of_neighbours' )# 为直方图呈现标签
for i in range(15):
    plt.text(arr[1][i],arr[0][i],str(arr[0][i]))
# 去除图形顶部边界和右边界的刻度
plt.tick_params(top='off', right='off')
# 显示图例
plt.legend()
# 显示图形
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# /usr/local/lib/python3.6/dist-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# log_num_of_neighbours
# 设置图形的显示风格
plt.style.use('ggplot')
# 绘图：乘客年龄的频数直方图
arr = plt.hist(df_statistics.log_num_of_in_neighbours, # 绘图数据
        bins = 15, # 指定直方图的条形数为20个
        color = 'steelblue', # 指定填充色
        edgecolor = 'k', # 指定直方图的边界色
        label = 'log_num_of_in_neighbours' )# 为直方图呈现标签
for i in range(15):
    plt.text(arr[1][i],arr[0][i],str(arr[0][i]))
# 去除图形顶部边界和右边界的刻度
plt.tick_params(top='off', right='off')
# 显示图例
plt.legend()
# 显示图形
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# /usr/local/lib/python3.6/dist-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# log_num_of_neighbours
# 设置图形的显示风格
plt.style.use('ggplot')
# 绘图：乘客年龄的频数直方图
arr = plt.hist(df_statistics.log_num_of_neighbours, # 绘图数据
        bins = 15, # 指定直方图的条形数为20个
        color = 'steelblue', # 指定填充色
        edgecolor = 'k', # 指定直方图的边界色
        label = 'log_num_of_neighbours' )# 为直方图呈现标签
for i in range(15):
    plt.text(arr[1][i],arr[0][i],str(arr[0][i]))
# 去除图形顶部边界和右边界的刻度
plt.tick_params(top='off', right='off')
# 显示图例
plt.legend()
# 显示图形
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# /usr/local/lib/python3.6/dist-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# # Modelling

# %% [markdown]
# # Please save the training set as the csv file.

# %%
from sklearn.linear_model.logistic import LogisticRegression
# TODO: Do we need to split the train and validation data via this one?
from sklearn.cross_validation import train_test_split
classifier = LogisticRegression()
classifier.fit(X_train, y_train)

# %% [markdown]
# # Prediction
